# %%
from PIL import Image
import matplotlib.pyplot as plt

from diffae import DiffusionAutoEncodersInterface

# %%
args = {
    'output': '../output/celebahq128',
    'model_ckpt': 'last_ckpt.pth',
    'clf_ckpt': 'clf_last_ckpt.pth',
}
mode = 'infer'
diffae = DiffusionAutoEncodersInterface(args, mode)
# Out:
# 2022-12-17 17:39:53.006 | INFO     | diffae.interface:_init_config:69 - Initializing config...
# 2022-12-17 17:39:53.065 | INFO     | diffae.interface:_init_model:103 - Initializing Diffusion Autoencoders...
# 2022-12-17 17:39:54.633 | INFO     | diffae.interface:_init_model:106 - Loading Diff-AE checkpoint...
# 2022-12-17 17:40:07.316 | INFO     | diffae.interface:_init_clf_model:114 - Initializing classifier...
# 2022-12-17 17:40:07.319 | INFO     | diffae.interface:_init_clf_model:117 - Loading classifier checkpoint...
# 2022-12-17 17:40:08.812 | INFO     | diffae.interface:_init_dataset:126 - Initializing dataset...

# %% [markdown]
# # Smiling

# %%
image = Image.open('../assets/celebahq_sample/53.jpg')
plt.imshow(image)

# %%
target_id = 31  # Smiling
s = [0.4, 0.6, 0.8, 1.0]
results = diffae.infer_manipulate(image, target_id=target_id, s=s)

fig, ax = plt.subplots(1, len(s), tight_layout=True)
for i, r in enumerate(results):
    ax[i].imshow(r['output'])
    ax[i].set_title(s[i])
    ax[i].axis('off')
fig.show()
# Out:
# 2022-12-17 17:40:09.526 | INFO     | diffae.interface:_init_clf_model:114 - Initializing classifier...
# 2022-12-17 17:40:09.529 | INFO     | diffae.interface:_init_clf_model:117 - Loading classifier checkpoint...
# stochastic encoding...: 100%|██████████| 1000/1000 [00:55<00:00, 18.00it/s]
# decoding...: 100%|██████████| 1000/1000 [00:56<00:00, 17.59it/s]
# decoding...: 100%|██████████| 1000/1000 [00:56<00:00, 17.78it/s]
# decoding...: 100%|██████████| 1000/1000 [00:54<00:00, 18.47it/s]
# decoding...: 100%|██████████| 1000/1000 [00:44<00:00, 22.59it/s]

# %% [markdown]
# # Young

# %%
image = Image.open('../assets/celebahq_sample/753.jpg')
plt.imshow(image)

# %%
target_id = 39  # Young
s = [1.0, 1.5, 2.0, 2.5]
results = diffae.infer_manipulate(image, target_id=target_id, s=s)

fig, ax = plt.subplots(1, len(s), tight_layout=True)
for i, r in enumerate(results):
    ax[i].imshow(r['output'])
    ax[i].set_title(s[i])
    ax[i].axis('off')
fig.show()
# Out:
# 2022-12-17 17:45:00.317 | INFO     | diffae.interface:_init_clf_model:114 - Initializing classifier...
# 2022-12-17 17:45:00.320 | INFO     | diffae.interface:_init_clf_model:117 - Loading classifier checkpoint...
# stochastic encoding...: 100%|██████████| 1000/1000 [00:39<00:00, 25.16it/s]
# decoding...: 100%|██████████| 1000/1000 [00:56<00:00, 17.70it/s]
# decoding...: 100%|██████████| 1000/1000 [00:55<00:00, 18.07it/s]
# decoding...: 100%|██████████| 1000/1000 [01:00<00:00, 16.66it/s]
# decoding...: 100%|██████████| 1000/1000 [00:57<00:00, 17.40it/s]
